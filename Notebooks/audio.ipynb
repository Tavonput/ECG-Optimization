# %%
import sys
sys.path.append("../")

import os

import torch
import torch.nn as nn
import torchaudio
from torchaudio.datasets import SPEECHCOMMANDS

import matplotlib.pyplot as plt
from IPython.display import Audio

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
data_dir = "../Data/Speech-Commands"
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

train_set = SPEECHCOMMANDS("../Data/Speech-Commands", download=True, subset="training")
test_set  = SPEECHCOMMANDS("../Data/Speech-Commands", download=True, subset="testing")
# Out:
# 100%|██████████| 2.26G/2.26G [00:32<00:00, 74.7MB/s]

# %%
waveform, sample_rate, label, speaker_id, utterance_number = train_set[0]

# %%
plt.plot(waveform.t().numpy());

# %%
resample_ratio = 4
transform = torchaudio.transforms.Resample(sample_rate, sample_rate/resample_ratio)
new_wave  = transform(waveform)

print(new_wave.shape)
plt.plot(new_wave.t().numpy())
# Out:
# torch.Size([1, 4000])
